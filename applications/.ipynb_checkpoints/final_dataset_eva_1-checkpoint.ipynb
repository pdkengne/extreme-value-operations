# %%
#'
path <- ".."

#'
xfun::in_dir(dir = path, expr = source("./src/generate_gev_sample.R"))
xfun::in_dir(dir = path, expr = source("./src/calculate_gev_inverse_cdf.R"))
xfun::in_dir(dir = path, expr = source("./src/estimate_gev_mixture_model_parameters.R"))
xfun::in_dir(dir = path, expr = source("./src/plot_gev_mixture_model_pdf.R"))
xfun::in_dir(dir = path, expr = source("./src/plot_gev_mixture_model_cdf.R"))
xfun::in_dir(dir = path, expr = source("./src/estimate_gev_mixture_model_quantile.R"))

# %%
library(readr)

# %%
data <- xfun::in_dir(dir = path, expr = read_csv("./applications/final_dataset.csv"))
# Out:
# Rows: 22847 Columns: 53
# ── Column specification ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (53): timestamp, latitude, longitude, velocity_latitude, velocity_longit...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#str(data)

# %%
options(repr.plot.width=19, repr.plot.height=12)

# %%
x <- abs(data$lateral_error)

# %%
dens_x <- density(x)
hist(x, prob = TRUE, ylim = range(dens_x$y))
lines(dens_x, lwd = 2, col = 4)
# Out:
# Plot with title “Histogram of x”

# %%
threshold_x <- 2.5
x <- x[x <= threshold_x]

# %%
hist(x)
# Out:
# Plot with title “Histogram of x”

# %%
nlargest <- 2000
y <- extract_nlargest_sample(x, n = nlargest)

# %%
dens_y <- density(y)
hist(y, prob = TRUE, ylim = range(dens_y$y))
lines(density(y), lwd = 2, col = 4)
# Out:
# Plot with title “Histogram of y”

# %%
gev_mixture_model <- suppressWarnings(estimate_gev_mixture_model_parameters(x = x, 
                                                                            block_sizes = 10:40,
                                                                            minimum_nblocks = 50,
                                                                            threshold = min(y),
                                                                            nlargest = nlargest,
                                                                            confidence_level = 0.95,
                                                                            use_extremal_index = TRUE,
                                                                            use_lower_threshold = FALSE,
                                                                            maximum_iterations = 1500,
                                                                            log_mv = TRUE,
                                                                            log_pw = TRUE,
                                                                            trace = FALSE,
                                                                            method = "MLE"))
# Out:
#   Successful convergence.
#   Successful convergence.

# %%
print(gev_mixture_model$extremal_indexes)
# Out:
#            10            11            12            13            14
# 0.07776278577 0.07345223522 0.05527206222 0.06893407268 0.05257368300
#            15            16            17            18            19
# 0.05527206222 0.05527206222 0.05429445816 0.05474747194 0.04495013207
#            20            21            22            23            24
# 0.05257368300 0.05112040823 0.04495013207 0.05112040823 0.04495013207
#            25            26            27            28            29
# 0.04495013207 0.04787681296 0.03793385167 0.03793385167 0.04787681296
#            30            31            32            33            34
# 0.04495013207 0.04495013207 0.03793385167 0.03519257577 0.04495013207
#            35            36            37            38            39
# 0.03793385167 0.03558892239 0.03793385167 0.03519257577 0.03793385167
#            40
# 0.03276548052

# %%
print(gev_mixture_model$normalized_gev_parameters_object)
# Out:
#        loc_star    scale_star   shape_star
# 10 0.8958302011 0.06883836393 0.3966872960
# 11 0.8861705411 0.07165448603 0.3723691379
# 12 0.8963836799 0.06143550449 0.4152585507
# 13 0.8803253924 0.06539948093 0.3836710999
# 14 0.9017535958 0.05321683650 0.4430468318
# 15 0.8571411012 0.07086490743 0.3496091453
# 16 0.8795218955 0.05722620091 0.4108086120
#                   loc_star     scale_star   shape_star
# automatic_weights 0.9017535958 0.1001681723 0.4430468318

# %%
print(gev_mixture_model$automatic_weights_mw)
# Out:
#               10               11               12               13
#  1.000000000e+00  2.486899575e-14  0.000000000e+00  0.000000000e+00
#               14               15               16               17
#  0.000000000e+00  0.000000000e+00  0.000000000e+00 -8.881784197e-16
#               18               19               20               21
#  0.000000000e+00  0.000000000e+00  0.000000000e+00  0.000000000e+00
#               22               23               24               25
# -8.881784197e-16  0.000000000e+00 -8.881784197e-16 -4.440892099e-16
#               26               27               28               29
# -4.440892099e-16  8.881784197e-16  8.881784197e-16 -8.881784197e-16
#               30               31               32               33
# -8.881784197e-16  1.332267630e-15 -1.776356839e-15  8.881784197e-16
#               34               35               36               37
# -1.332267630e-15  4.440892099e-16  1.332267630e-15  8.881784197e-16
#               38               39               40
# -4.440892099e-16  8.881784197e-16  0.000000000e+00

# %%
plot_gev_mixture_model_pdf(gev_mixture_model,
                           type = "automatic_weights",
                           model_wise = FALSE,
                           zoom = TRUE,
                           xlab = "Quantile",
                           ylab = "Density",
                           main = "Probability Density Function (PDF) Plot")
# Out:
# Plot with title “Probability Density Function (PDF) Plot : automatic_weights - model_wise = FALSE : zoom = TRUE”

# %%
plot_gev_mixture_model_pdf(gev_mixture_model,
                           type = "automatic_weights",
                           model_wise = TRUE,
                           zoom = TRUE,
                           xlab = "Quantile",
                           ylab = "Density",
                           main = "Probability Density Function (PDF) Plot")
# Out:
# Plot with title “Probability Density Function (PDF) Plot : automatic_weights - model_wise = TRUE : zoom = TRUE”

# %%
estimator_types <- c("automatic_weights_mw", 
                     "pessimistic_weights_mw", 
                     "identic_weights_mw", 
                     "automatic_weights_pw",
                     "pessimistic_weights_pw", 
                     "identic_weights_pw", 
                     "model_wise",
                     "parameter_wise",
                     "empirical")

# %%
alpha <- 10^(-14)

# %%
rl_mw <- estimate_gev_mixture_model_quantile(gev_mixture_model,
                                             alpha = alpha,
                                             confidence_level = 0.95,
                                             do.ci = TRUE,
                                             estimator_type = estimator_types[1])

rl_mw
# Out:
# [1] 8630.040701

# %%
rl_pw <- estimate_gev_mixture_model_quantile(gev_mixture_model,
                                             alpha = alpha,
                                             confidence_level = 0.95,
                                             do.ci = TRUE,
                                             estimator_type = estimator_types[4])

rl_pw
# Out:
# [1] 123392.0558

# %%
est_rl_pw <- suppressWarnings(estimate_gev_mixture_model_quantile(gev_mixture_model,
                                                                  alpha = alpha,
                                                                  confidence_level = 0.95,
                                                                  do.ci = TRUE,
                                                                  estimator_type = estimator_types[8]))

est_rl_pw
# Out:
#    lower          quantile      upper
# 10  -35948.495054  8233.0505006  52414.596055
# 11  -20314.225572  4756.3245188  29826.874610
# 12  -54077.347644 10595.4834426  75268.314529
# 13  -28402.941989  5604.3107055  39611.563400
# 14 -101288.298086 17747.1145379 136782.527161
# 15  -13369.693457  2479.2086805  18328.110818
# 16  -52876.006119  8850.2356189  70576.477357
# 17  -14830.278880  2650.7807309  20131.840342
# 18  -40902.776760  6753.1668040  54409.110368
# 19  -53213.281839  7643.0384095  68499.358658
# 20  -16499.207185  2579.5991269  21658.405438
# 21  -50747.952611  7342.0831936  65432.118999
# 22  -57931.496322  7888.7030411  73708.902404
# 23  -55692.395602  7799.4493273  71291.294257
# 24  -38407.034091  4769.7483771  47946.530845
# 25   -6690.729482  1003.3650975   8697.459677
# 26  -21004.621824  2851.4604393  26707.542702
# 27  -12560.384297  1716.7414986  15993.867294
# 28  -18449.583533  2367.5059914  23184.595516
# 29  -21887.531111  2681.7676338  27251.066378
# 30   -6081.031095   855.4073471   7791.845789
# 31  -10797.628076  1413.6336014  13624.895278
# 32   -7469.819819   964.0184960   9397.856811
# 33  -35206.660830  3725.8897064  42658.440243
# 34  -19273.031535  2411.1461939  24095.323923
# 35  -27598.017453  3089.3517905  33776.721034
# 36  -18329.163863  2013.6397103  22356.443284
# 37   -8508.934336  1023.8497540  10556.633844
# 38  -10504.670945  1153.6769617  12812.024868
# 39   -1325.454128   190.5550577   1706.564243
# 40  -31370.390709  3128.2696764  37626.930062

# %%
est_rl_pw_range <- range(as.matrix(est_rl_pw))

# %%
est_rl_mw <- suppressWarnings(estimate_gev_mixture_model_quantile(gev_mixture_model,
                                                                  alpha = alpha,
                                                                  confidence_level = 0.95,
                                                                  do.ci = TRUE,
                                                                  estimator_type = estimator_types[7]))
est_rl_mw
# Out:
#    lower         quantile     upper
# 10 -35948.495054 8233.0505006 52414.596055
# 11 -20314.225572 4756.3245188 29826.874610
# 27 -12560.384297 1716.7414986 15993.867294
# 28 -18449.583533 2367.5059914 23184.595516
# 31 -10797.628076 1413.6336014 13624.895278
# 33 -35206.660830 3725.8897064 42658.440243
# 35 -27598.017453 3089.3517905 33776.721034
# 36 -18329.163863 2013.6397103 22356.443284
# 37  -8508.934336 1023.8497540 10556.633844
# 39  -1325.454128  190.5550577  1706.564243

# %%
est_rl_mw_range <- range(as.matrix(est_rl_mw))

est_rl_mw_range
# Out:
# [1] -35948.49505  52414.59606

# %%
matplot(x = rownames(est_rl_pw), 
        y = est_rl_pw, 
        xlab = "block size",
        ylab = "quantile",
        main = "Estimates of a quantile",
        ylim = range(c(est_rl_pw_range, rl_pw)),
        cex = 1,
        cex.lab = 1,
        cex.axis = 1,
        type = "l", 
        lty = c("dotted", "solid", "dotted"), 
        lwd = c(2,2,2), 
        col = c(3, 1, 3))

abline(h = rl_mw, col = 7, lwd = 2)
abline(h = rl_pw, col = 6, lwd = 2)
abline(h = est_rl_pw_range, col = 6, lty = "dotted", lwd = 2)
abline(h = est_rl_mw_range, col = 7, lty = "dotted", lwd = 2)
# Out:
# Plot with title “Estimates of a quantile”

# %%
# Legend:
# yellow: Quantile from GEV mixture model with respect to distribution functions
# pink: Quantile from GEV mixture model with respect to parameters
