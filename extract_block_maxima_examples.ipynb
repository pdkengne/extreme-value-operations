# %%
source("./src/extract_block_maxima.R")

# %%
# example 1

x <- rnorm(n = 1000)

results <- extract_block_maxima(x, block_size = 50)

print(results)
# Out:
#  [1] 1.791064 1.853380 1.970695 1.565792 1.540808 2.808076 2.046535 2.411705
#  [9] 1.960070 1.757119 3.551471 2.156650 2.458919 2.330175 1.389123 1.973738
# [17] 1.980532 3.337972 2.394790 2.509374

# %%
options(repr.plot.width=12, repr.plot.height=8)
plot(results)
# Out:
# plot without title

# %%
# example 2
 
x <- 1:1000
 
results <- extract_block_maxima(x, block_size = 50)

print(results)
# Out:
#  [1]   50  100  150  200  250  300  350  400  450  500  550  600  650  700  750
# [16]  800  850  900  950 1000
