# %% [markdown]
# # input argument

# %%
# enter dataset directory

experimentation_dir_1 <- "./20231026_094602_Record_data_INRIA"

experimentation_dir_2 <- "./112048_20231211_165719_Record_data_INRIA"

experimentation_dir_3 <- "./105635_20231212_101549_Record_data_INRIA"

experimentation_dir_4 <- "./114823_20231212_104522_Record_data_INRIA"

# %%
# set the considered directory
paths <- "."

main_dir <- xfun::in_dir(dir = paths, expr = experimentation_dir_4)

# %% [markdown]
# # split images

# %%
# load create functions
xfun::in_dir(dir = paths, expr = source("./etl_pipeline/src/01_split_images.R"))

# %%
# use create functions
split_several_jpg_images(main_dir = main_dir, split_size = 400)
# Out:
# [[1]]
# NULL
#
# [[2]]
# NULL
#
# [[3]]
# NULL
#
# [[4]]
# NULL
#
# [[5]]
# NULL
#
# [[6]]
# NULL
#
# [[7]]
# NULL
#
# [[8]]
# NULL
#
# [[9]]
# NULL
#
# [[10]]
# NULL
#
# [[11]]
# NULL
#
# [[12]]
# NULL
#
# [[13]]
# NULL
#
# [[14]]
# NULL
#
# [[15]]
# NULL
#
# [[16]]
# NULL
#
# [[17]]
# NULL
#
# [[18]]
# NULL
#
# [[19]]
# NULL
#
# [[20]]
# NULL
#
# [[21]]
# NULL
#
# [[22]]
# NULL
#
# [[23]]
# NULL
#
# [[24]]
# NULL
#
# [[25]]
# NULL
#
# [[26]]
# NULL
#
# [[27]]
# NULL
#
# [[28]]
# NULL
#
# [[29]]
# NULL
#
# [[30]]
# NULL
#
# [[31]]
# NULL
#
# [[32]]
# NULL
#
# [[33]]
# NULL
#
# [[34]]
# NULL
#
# [[35]]
# NULL
#
# [[36]]
# NULL
#
# [[37]]
# NULL
#
# [[38]]
# NULL
#
# [[39]]
# NULL
#
# [[40]]
# NULL
#
# [[41]]
# NULL
#
# [[42]]
# NULL
#
# [[43]]
# NULL
#
# [[44]]
# NULL
#
# [[45]]
# NULL
#
# [[46]]
# NULL
#
# [[47]]
# NULL
#
# [[48]]
# NULL
#
# [[49]]
# NULL
#
# [[50]]
# NULL
#
# [[51]]
# NULL
#
# [[52]]
# NULL
#
# [[53]]
# NULL
#
# [[54]]
# NULL
#
# [[55]]
# NULL
#
# [[56]]
# NULL
#
# ...

# %% [markdown]
# # detect objects

# %%
# load create functions
library(reticulate)

use_virtualenv("./yolov5_venv")

xfun::in_dir(dir = paths, expr = source_python("./etl_pipeline/src/02_detect_objects.py"))

# %%
# use create functions
detect_objects_from_jpg_images(main_dir = main_dir)

# exit the used virtual environment
use_python("/usr/bin/python3", required = NULL)

# %% [markdown]
# # extract detection

# %%
# load create functions
xfun::in_dir(dir = paths, expr = source("./etl_pipeline/src/03_extract_detections.R"))

# %%
# use create functions
extract_detection(main_dir = main_dir)
# Out:
# [1] "The following file already exists: ./114823_20231212_104522_Record_data_INRIA/extracted_detections.csv"

# %% [markdown]
# # transform detections

# %%
# load create functions
xfun::in_dir(dir = paths, expr = source("./etl_pipeline/src/04_transform_detections.R"))
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Loading required package: lattice
#
#
# Attaching package: ‘caret’
#
#
# The following object is masked from ‘package:purrr’:
#
#     lift

# %%
# use create functions
transform_detections(main_dir = main_dir)
# Out:
# [1] "The following file already exists: ./114823_20231212_104522_Record_data_INRIA/transformed_detections.csv"

# %% [markdown]
# # merge data

# %%
# load create functions
xfun::in_dir(dir = paths, expr = source("./etl_pipeline/src/05_merge_data.R"))

# %%
# use create functions
merge_data(main_dir = main_dir)
# Out:
# [1] "The following file already exists: ./114823_20231212_104522_Record_data_INRIA/merged_data.csv"
